# %% [markdown]
# **1.1**

# %% [markdown]
# read csv

# %%
import pandas as pd
import numpy as np


data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/IDBI.csv")
data
# Out:
#     Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0     IDBI     EQ  ...         1486475                   22.22
# 1     IDBI     EQ  ...         2578070                   29.50
# 2     IDBI     EQ  ...          643174                   20.40
# 3     IDBI     EQ  ...         2852529                   18.91
# 4     IDBI     EQ  ...         1949156                   17.77
# ..     ...    ...  ...             ...                     ...
# 489   IDBI     EQ  ...         1494438                   34.74
# 490   IDBI     EQ  ...          791164                   19.83
# 491   IDBI     EQ  ...          817079                   19.58
# 492   IDBI     EQ  ...         1735179                   33.15
# 493   IDBI     EQ  ...         1732376                   27.60
#
# [494 rows x 15 columns]

# %% [markdown]
# head()

# %%
data.head()
# Out:
#   Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 0   IDBI     EQ  ...         1486475                   22.22
# 1   IDBI     EQ  ...         2578070                   29.50
# 2   IDBI     EQ  ...          643174                   20.40
# 3   IDBI     EQ  ...         2852529                   18.91
# 4   IDBI     EQ  ...         1949156                   17.77
#
# [5 rows x 15 columns]

# %% [markdown]
# Tail()

# %%
data.tail()
# Out:
#     Symbol Series  ... Deliverable Qty  % Dly Qt to Traded Qty
# 489   IDBI     EQ  ...         1494438                   34.74
# 490   IDBI     EQ  ...          791164                   19.83
# 491   IDBI     EQ  ...          817079                   19.58
# 492   IDBI     EQ  ...         1735179                   33.15
# 493   IDBI     EQ  ...         1732376                   27.60
#
# [5 rows x 15 columns]

# %% [markdown]
# describe()

# %%
data.describe()
# Out:
#        Prev Close  Open Price  ...  Deliverable Qty  % Dly Qt to Traded Qty
# count  494.000000  494.000000  ...     4.940000e+02              494.000000
# mean    58.529960   58.628441  ...     1.570701e+06               19.155223
# std      8.132574    8.131273  ...     1.527126e+06               10.125048
# min     37.050000   36.650000  ...     1.159420e+05                2.990000
# 25%     55.187500   55.300000  ...     5.729168e+05               12.042500
# 50%     59.450000   59.600000  ...     1.055646e+06               17.400000
# 75%     62.000000   62.037500  ...     1.937686e+06               23.167500
# max     84.650000   85.500000  ...     1.080873e+07               80.850000
#
# [8 rows x 12 columns]

# %% [markdown]
# **1.2**

# %% [markdown]
# max()

# %%
Maximum = data['Close Price'].max()

# %% [markdown]
# min()

# %%
Minimum = data['Close Price'].min()

# %% [markdown]
# mean()

# %%
Mean = data['Close Price'].mean()

# %%
print("Maximum =",Maximum)
print("minimum =",Minimum)
print("Mean =",Mean)
# Out:
# Maximum = 84.65
# minimum = 34.45
# Mean = 58.44686234817817

# %% [markdown]
# **1.3**

# %%
data=data.assign(Day_perc_change=np.nan)
data
# Out:
#     Symbol Series  ... % Dly Qt to Traded Qty  Day_perc_change
# 0     IDBI     EQ  ...                  22.22              NaN
# 1     IDBI     EQ  ...                  29.50              NaN
# 2     IDBI     EQ  ...                  20.40              NaN
# 3     IDBI     EQ  ...                  18.91              NaN
# 4     IDBI     EQ  ...                  17.77              NaN
# ..     ...    ...  ...                    ...              ...
# 489   IDBI     EQ  ...                  34.74              NaN
# 490   IDBI     EQ  ...                  19.83              NaN
# 491   IDBI     EQ  ...                  19.58              NaN
# 492   IDBI     EQ  ...                  33.15              NaN
# 493   IDBI     EQ  ...                  27.60              NaN
#
# [494 rows x 16 columns]

# %%
data.Day_perc_change = data['Close Price'].pct_change()
data
# Out:
#     Symbol Series  ... % Dly Qt to Traded Qty  Day_perc_change
# 0     IDBI     EQ  ...                  22.22              NaN
# 1     IDBI     EQ  ...                  29.50         0.021319
# 2     IDBI     EQ  ...                  20.40        -0.009132
# 3     IDBI     EQ  ...                  18.91        -0.078999
# 4     IDBI     EQ  ...                  17.77        -0.017155
# ..     ...    ...  ...                    ...              ...
# 489   IDBI     EQ  ...                  34.74        -0.034974
# 490   IDBI     EQ  ...                  19.83        -0.005369
# 491   IDBI     EQ  ...                  19.58         0.010796
# 492   IDBI     EQ  ...                  33.15        -0.005340
# 493   IDBI     EQ  ...                  27.60        -0.075168
#
# [494 rows x 16 columns]

# %% [markdown]
# **1.4**

# %%
import matplotlib.pyplot as plt
data.Date=pd.to_datetime(data.Date)
plt.style.use('seaborn')
x=data['Date']
y=data['Close Price']
plt.plot(x,y)
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# **1.5**

# %%
data
# Out:
#     Symbol Series  ... % Dly Qt to Traded Qty  Day_perc_change
# 0     IDBI     EQ  ...                  22.22              NaN
# 1     IDBI     EQ  ...                  29.50         0.021319
# 2     IDBI     EQ  ...                  20.40        -0.009132
# 3     IDBI     EQ  ...                  18.91        -0.078999
# 4     IDBI     EQ  ...                  17.77        -0.017155
# ..     ...    ...  ...                    ...              ...
# 489   IDBI     EQ  ...                  34.74        -0.034974
# 490   IDBI     EQ  ...                  19.83        -0.005369
# 491   IDBI     EQ  ...                  19.58         0.010796
# 492   IDBI     EQ  ...                  33.15        -0.005340
# 493   IDBI     EQ  ...                  27.60        -0.075168
#
# [494 rows x 16 columns]

# %%
plt.style.use('seaborn')
plt.xlabel('Date')
a = data['Date']
b = data['Day_perc_change']
plt.stem(a,b)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """
# <StemContainer object of 3 artists>

# %% [markdown]
# **1.6**

# %%
x = data['Day_perc_change']
plt.xlabel("Day_perc_change")
plt.hist(x)
# Out:
# (array([ 23.,  43., 218., 163.,  33.,   9.,   3.,   0.,   0.,   1.]),
#  array([-0.08274399, -0.05448801, -0.02623202,  0.00202396,  0.03027994,
#          0.05853592,  0.08679191,  0.11504789,  0.14330387,  0.17155986,
#          0.19981584]),
#  <a list of 10 Patch objects>)
